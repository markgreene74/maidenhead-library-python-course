# %% [markdown]
# # Maidenhead Library Python course

# %% [markdown]
# Welcome! This is the material for the Python course at the Maidenhead Library.
#
# You should be able to run this notebook in Binder.

# %% [markdown]
# ## Placeholder

# %% [markdown]
# At the moment this is just an example with snippets taken from [the Seaborn gallery](https://seaborn.pydata.org/examples/index.html) to show that everything is working.

# %% [markdown]
# ---

# %% [markdown]
# ### Imports

# %%
# %matplotlib inline
import seaborn as sns
import numpy as np

# %% [markdown]
# ### Example 1 (Timeseries plot with error bands)

# %%
sns.set_theme(style="darkgrid")

# Load an example dataset with long-form data
fmri = sns.load_dataset("fmri")

# Plot the responses for different events and regions
sns.lineplot(x="timepoint", y="signal",
             hue="region", style="event",
             data=fmri)
# Out:
# <Axes: xlabel='timepoint', ylabel='signal'>

# %% [markdown]
# ### Example 2 (Hexbin plot with marginal distributions)

# %%
sns.set_theme(style="ticks")

rs = np.random.RandomState(11)
x = rs.gamma(2, size=1000)
y = -.5 * x + rs.normal(size=1000)

sns.jointplot(x=x, y=y, kind="hex", color="#4CB391")
